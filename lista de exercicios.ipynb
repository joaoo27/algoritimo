# %%
print ("1) adiçao")

a = float(input ("insira um numero: "))
b = float(input ("insira um numero: "))

soma = a + b

print(soma)
# Out:
# adiçao
# insira um numero: 1
# insira um numero: 2
# 3.0

# %%
print("2) subtraçao")

a = float(input ("insira um numero: "))
b = float(input ("insira um numero: "))

sub = a - b

print(sub)
# Out:
# subtraçao
# insira um numero: 3
# insira um numero: 1
# 2.0

# %%
print("3) multiplicaçao")

a = float(input ("insira um numero: "))
b = float(input ("insira um numero: "))

mult = a * b

print(mult)
# Out:
# multiplicaçao
# insira um numero: 2
# insira um numero: 2
# 4.0

# %%
print("4) divisao")

a = float(input ("insira um numero: "))
b = float(input ("insira um numero: "))

div = a / b

print(div)
# Out:
# divisao
# insira um numero: 10
# insira um numero: 5
# 2.0

# %%
print("5) dobro e triplo")

a = float(input ("insira um numero: "))

print(f"\n dobro: {a * 2}\n triplo: {a * 3} ")
# Out:
# dobro e triplo
# insira um numero: 2
#
#  dobro: 4.0
#  triplo: 6.0

# %%
print("6) antecessor e sucessor")

a = float(input ("insira um numero: "))


print(f"\n sucessor: {a + 1}\n sntecessor: {a - 1} ")
# Out:
# antecessor e sucessor
# insira um numero: 2
#
#  sucessor: 3.0
#  sntecessor: 1.0

# %%
print ("7) area triangulo")

b = float(input ("insira a base: "))
h = float(input ("insira a altura: "))

area = (b * h) / 2

print(f"area do triangulo: {area}")
# Out:
# area triangulo
# insira a base: 4
# insira a altura: 6
# area do triangulo: 12.0

# %%
print ("8) perimetro retangulo")

b = float(input ("insira a base: "))
h = float(input ("insira a altura: "))

per = 2 * (b + h)

print(f"perimetro do retangulo: {per}")
# Out:
# perimetro retangulo
# insira a base: 5
# insira a altura: 4
# perimetro do retangulo: 18.0

# %%
print ("9) postivo e negativo")

num = int(input("insira um numero: "))

if num == 0:
    print("zero")

elif num > 0:
  print ("positivo")

elif num < 0:
  print ("negativo")
# Out:
# postivo e negativo
# insira um numero: -1
# negativo

# %%
print ("10) par ou impar")

num = int(input ("insira um numero: "))


if num % 2 == 0:
  print ("par")

elif num % 2 != 0:
  print ("impar")
# Out:
# positivo negativo ou zero
# insira um numero: 0
# zero

# %%
print ("11) maior entre dois numeros")

num = int(input ("insira um numero: "))
num2 = int(input ("insira outro numero: "))

if num > num2:
  print (f"o maior numero é {num}")

elif num2 > num:
  print (f"o maior numero é {num2}")

else:
  print("numeros iguais")
# Out:
# maior entre dois numeros
# insira um numero: 1
# insira outro numero: 2
# o maior numero é 2

# %%
print ("12) maior entre tres numeros")

num = int(input ("insira um numero: "))
num2 = int(input ("insira outro numero: "))
num3 = int(input ("insira outro numero: "))

if num > num2 and num > num3:
  print (f"o maior numero é {num}")

elif num2 > num and num2 > num3:
  print (f"o maior numero é {num2}")

elif num3 > num and num3 > num2:
  print (f"o maior numero é {num33}")

else:
  print("numeros iguais")
# Out:
# maior entre tres numeros
# insira um numero: 3
# insira outro numero: 3
# insira outro numero: 3
# numeros iguais

# %%
print ("13) quem pode votar")

idade = int (input("idade: "))
titulo = bool (input("possui titulo de eleitor?(s/n): "))
tituloe = True

if titulo.lower() == "n":
  tituloe = False

else:
    tituloe = True

if idade>= 16 and tituloe:
  print("pode votar")

else:
    print ("nao pode votar")
# Out:
# quem pode votar
# idade: 16
# possui titulo de eleitor?(s/n): s
# pode votar

# %%
print ("14) quem pode dirigir")

idade = int (input("idade: "))
cnhp = bool = (input("possui cnh?(s/n): "))
cnh = True

if cnhp.lower() == "n":
  cnh = False

else:
    cnh = True

if idade>= 18 and cnh:
  print("pode dirigir")

else:
    print ("nao pode dirigir")
# Out:
# quem pode dirigir
# idade: 18
# possui cnh?(s/n): n
# nao pode dirigir

# %%
print ("15) desconto 10% a vista")

valor = float (input("valor da compra: "))
pagamento = input("forma de pagamento?(crédito/ débito/ a vista): ")
desconto = float

if pagamento.lower() == "a vista":
  print(f"o valor da compra com desconto é de: {valor - (valor * 0.10)}")

else:
    print (f"o valor da compra sem desconto é de: {valor}")
# Out:
# desconto 10% a vista
# valor da compra1500
# forma de pagamento?(crédito/ débito/ a vista): a vista
# o valor da compra com desconto é de: 1350.0

# %%
print ("16) aumento 15% salario até 2000")

salario = float (input("salario atual: "))
aumento = input("aumento autorizado?: ")

if salario <= 2000 and aumento.lower() == "sim":
  aumento == True
  print(f"o salario com o aumento é de: {salario + (salario * 0.15)}")

else:
  aumento == False
  print(f"o salario continua sendo: {salario}")
# Out:
# aumento 15% salario até 2000
# salario atual: 3000
# aumento autorizado?: sim
# o salario continua sendo: 3000.0

# %%
print ("17) numero valido")

numero = int(input("digite um numero de 10 a 50: "))

if numero >= 10 and numero <= 50:
  print("numero valido")

else:
  print("numero invalido")

# %%
print("18) cadastro de senha")

senha = input("Crie uma senha (minimo 6 caracteres): ")
confirmar_senha = input("Confirme a senha: ")

if len(senha) < 6:
  print("Senha invalida! Minimo de 6 caracteres.")

elif senha != confirmar_senha:
  print("As senhas nao coincidem!")

else:
  print("Senha cadastrada com sucesso!")

# %%
print("19) entrada de evento")

idade = int(input("Insira sua idade: "))
tem_ingresso = input("Possui ingresso? (S/N): ")

if idade >= 18 and tem_ingresso.lower() == "s":
  print("Entrada liberada!")

else:
  print("Entrada negada!")

# %%
print("20) calculadora simples")

num1 = float(input("Insira o primeiro numero: "))
operador = input("Insira a operacao (+, -, *, /): ")
num2 = float(input("Insira o segundo numero: "))

if operador == "+":
  print(f"Resultado = {num1 + num2}")

elif operador == "-":
  print(f"Resultado = {num1 - num2}")

elif operador == "*":
  print(f"Resultado = {num1 * num2}")

elif operador == "/":
  print(f"Resultado = {num1 / num2}")

else:
  print("Operacao invalida!")

# %%
print("21) pratica esportiva")

idade = int(input("Insira sua idade: "))

if idade >= 12 and idade <= 17:
  autorizacao = input("Possui autorizacao dos responsaveis? (S/N): ")

  if autorizacao.lower() == "s":
    print("Pode praticar o esporte!")

  else:
    print("Nao pode praticar sem autorizacao!")

elif idade > 17:
  print("Pode praticar o esporte!")

else:
  print("Idade minima nao atingida!")

# %%
print("22) esta chovendo?")

chovendo = input("Esta chovendo? (S/N): ")

if chovendo.lower() == "s":
  print("Leve um guarda-chuva!")

else:
  print("Nao precisa de guarda-chuva!")

# %%
print("23) classificacao de idade")

idade = int(input("Insira sua idade: "))

if idade <= 12:
  print("Crianca!")

elif idade <= 17:
  print("Adolescente!")

elif idade <= 59:
  print("Adulto!")

else:
  print("Idoso!")

# %%
print("24) classificacao de triangulo")

lado1 = float(input("Insira o primeiro lado: "))
lado2 = float(input("Insira o segundo lado: "))
lado3 = float(input("Insira o terceiro lado: "))

if lado1 == lado2 == lado3:
  print("Triangulo Equilatero!")

elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
  print("Triangulo Isosceles!")

else:
  print("Triangulo Escaleno!")

# %%
print("25) opcoes de pagamento da loja")

valor_produto = float(input("Insira o valor do produto: "))

print("Escolha a forma de pagamento:")
print("1 - Dinheiro/Pix")
print("2 - Cartao de debito")
print("3 - Cartao de credito")

opcao = input("Opcao: ")

if opcao == "1":
  print(f"Valor a pagar: {valor_produto * 0.9:.2f} (10% de desconto)")

elif opcao == "2":
  print(f"Valor a pagar: {valor_produto:.2f} (sem desconto)")

elif opcao == "3":
  print(f"Valor a pagar: {valor_produto * 1.05:.2f} (5% de acrescimo)")

else:
  print("Opcao invalida!")

# %%
print("26) descontos progressivos")

quantidade = int(input("Insira a quantidade de produtos vendidos: "))

if quantidade <= 5:
  desconto = 0

elif quantidade <= 10:
  desconto = 10

elif quantidade <= 20:
  desconto = 15

else:
  desconto = 30

print(f"Desconto aplicado: {desconto}%")
